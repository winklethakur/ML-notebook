# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl','rb'))
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Assume user input
test_input2 = np.array([2, 'female', 19.0, 0, 0, 26.0000, 'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# /home/winkle/.local/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /home/winkle/.local/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])

# %%
test_input =np.array([2, 'female', 8.0, 0, 2, 26.2500, 'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input)
# Out:
# /home/winkle/.local/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /home/winkle/.local/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
