# %%
import numpy as np

# %%
np.random.random()  # get random value again and again

# %%
np.random.seed(1)  # seed(1) will return same value after multiple exicution.
np.random.random()

# %%
np.random.uniform(1,5) # it will return random float value with in a range.

# %%
np.random.uniform(1,100,12).reshape(4,3)

# %%
np.random.randint(1,10)  #give a random integer value with in a given range.

# %%
np.random.randint(1,10,5) # range 1 to 10 and an array in a size of 5.

# %%
np.random.randint(1,10,6).reshape(3,2)  # 2D array.

# %%
a = np.random.randint(1,10,6)
a

# %%
# find max of this array.
np.max(a)

# %%
# find min
np.min(a)

# %%
# find the index of max value in an array.
np.argmax(a)

# %%
# find the index of min value in an array.
np.argmin(a)

# %%
a = np.random.randint(1,10,6)
a

# %%
# change the odd value to -1 in an array.
a[a%2==1]=-1
a

# %%
# change values using where clause.
a = np.random.randint(1,20,6)
a

# %%
# where(condition,true,false)
out = np.where(a%2==1,-1,a)
out

# %%
a = np.random.randint(1,50,10)
a

# %%
# sort the values 
a = np.sort(a)
a

# %%
# percentile

# %%
np.percentile(a,30)

# %%
np.percentile(a,50)
